# %% [markdown]
# # 02b — Baseline Attribution (shard: prompt row 160 onward)
#
# Duplicate of **`02_baseline_attribution.ipynb`** for a **second RunPod**:
#
# - Processes only prompts from **row 160** onward in **`prompts_triangle_v2.jsonl`** file order (skips rows 1–159). Adjust `START_PROMPT_ROW` in the dataset cell if needed.
# - Writes stats to **`results/statistics/stats_base_v2_from160.json`** so it does **not** race against the primary pod writing `stats_base_v2.json`. **Merge offline** after both finish if you want one combined JSON.
# - **Graphs** still go to `results/graphs_base_v2/` (prompt IDs are disjoint from the first pod’s range; no filename overlap if pod 1 only runs 1–159).
#
# **Run as a script** to avoid kernel timeouts:
# ```bash
# jupyter nbconvert --to script 02_baseline_attribution_pod2_from160.ipynb
# python 02_baseline_attribution_pod2_from160.py
# ```
#
# Saves incrementally (every prompt) so a restart resumes from the last checkpoint.
#
# **Prerequisites:** `01_dataset_generation.ipynb` must have been run (v2 cell).

# %% [markdown]
# ## 0 — Environment Setup

# %%
import os
import sys
from pathlib import Path

# Must be set BEFORE torch is imported anywhere to take effect.
# Prevents CUDA allocator fragmentation on long sequential attribution loops
# (without this, OOMs appear around prompt 12 even when VRAM is nominally free).
os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")

IN_RUNPOD = os.environ.get("RUNPOD_POD_ID") is not None

def _find_repo_root():
    start = Path.cwd().resolve()
    for directory in [start, *start.parents]:
        if (directory / "circuit_tracer" / "__init__.py").is_file():
            return directory
    workspace = Path("/workspace")
    if workspace.is_dir():
        for child in workspace.iterdir():
            if child.is_dir() and (child / "circuit_tracer" / "__init__.py").is_file():
                return child
    repo_override = os.environ.get("CT_REPO_DIR")
    if repo_override:
        override_path = Path(repo_override).expanduser().resolve()
        if (override_path / "circuit_tracer" / "__init__.py").is_file():
            return override_path
    return None

_root = _find_repo_root()
if _root is not None:
    if str(_root) not in sys.path:
        sys.path.insert(0, str(_root))
    _my_work = _root / "my_work"
    if str(_my_work) not in sys.path:
        sys.path.insert(0, str(_my_work))
    print(f"Repo root: {_root}")
else:
    print("WARNING: could not locate circuit_tracer repo.")

try:
    from dotenv import load_dotenv
    if _root is not None and (_root / ".env").is_file():
        load_dotenv(_root / ".env")
        print("Loaded .env")
except ImportError:
    pass

# Persistent HF cache for RunPod
if IN_RUNPOD:
    persistent_root = Path(os.environ.get("RUNPOD_PERSISTENT_ROOT", "/workspace")).resolve()
    hf_home = persistent_root / "hf"
    for key, path in {
        "HF_HOME": hf_home,
        "HUGGINGFACE_HUB_CACHE": hf_home / "hub",
        "TRANSFORMERS_CACHE": hf_home / "transformers",
    }.items():
        path.mkdir(parents=True, exist_ok=True)
        os.environ[key] = str(path)
    print(f"RunPod cache: {hf_home}")

MY_WORK = _my_work if _root else Path(".").resolve()
print(f"MY_WORK: {MY_WORK}")
# Out:
# Repo root: /workspace/thesis_circuit_breaker
# RunPod cache: /workspace/hf
# MY_WORK: /workspace/thesis_circuit_breaker/my_work

# %% [markdown]
# ## 1 — Imports & constants

# %%
import json
import time
import traceback

import torch
import numpy as np

# ── Plan constants (never change) ──────────────────────────────────────────────
MODEL_NAME      = "google/gemma-2-2b"
TRANSCODER_NAME = "gemma"
TOKEN_TRUE      = " True"
TOKEN_FALSE     = " False"
VOCAB_ID_TRUE   = 5569
VOCAB_ID_FALSE  = 7662

ATTR_KWARGS = dict(
    batch_size=256,
    max_feature_nodes=8192,
    offload="disk",
    verbose=False,
)

PHASE = "base"

# ── Paths ──────────────────────────────────────────────────────────────────────
# v2: uses supervisor-aligned factorial prompt set and separate stats file.
# Pilot stats (stats_base.json from v1 run) are left untouched.
DATASET_FILE   = MY_WORK / "data" / "prompts_triangle_v2.jsonl"
GRAPHS_DIR     = MY_WORK / "results" / "graphs_base_v2"
# Dedicated stats file so a second GPU pod does not clobber stats_base_v2.json
STATS_FILE     = MY_WORK / "results" / "statistics" / "stats_base_v2_from160.json"

GRAPHS_DIR.mkdir(parents=True, exist_ok=True)
STATS_FILE.parent.mkdir(parents=True, exist_ok=True)

print(f"Dataset file  : {DATASET_FILE}")
print(f"Graphs dir    : {GRAPHS_DIR}")
print(f"Stats output  : {STATS_FILE}")
print(f"CUDA available: {torch.cuda.is_available()}")

# ReplacementModel.from_pretrained expects a torch.device, not a plain string.
device_str = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_str)
print(f"Device        : {device}")
# Out:
# Dataset file  : /workspace/thesis_circuit_breaker/my_work/data/prompts_triangle_v2.jsonl
# Graphs dir    : /workspace/thesis_circuit_breaker/my_work/results/graphs_base_v2
# Stats output  : /workspace/thesis_circuit_breaker/my_work/results/statistics/stats_base_v2_from160.json
# CUDA available: True
# Device        : cuda

# %% [markdown]
# ## 2 — Load dataset, then shard (from prompt row ≥ 160)
#
# Reads the full `jsonl`, then drops rows **before** `START_PROMPT_ROW` (file order matches generation order).

# %%
START_PROMPT_ROW = 160  # 1-based row index in prompts_triangle_v2.jsonl (first row = 1)
_start = START_PROMPT_ROW - 1  # slice index into list

analysis_prompts = []
with open(DATASET_FILE, "r", encoding="utf-8") as f:
    for line in f:
        analysis_prompts.append(json.loads(line.strip()))

_n_full = len(analysis_prompts)
if _start > 0:
    analysis_prompts = analysis_prompts[_start:]
if not analysis_prompts:
    raise ValueError(f"No prompts after slice: START_PROMPT_ROW={START_PROMPT_ROW}, file had {_n_full} rows")

binary = [p for p in analysis_prompts if p.get("task_type", "binary") == "binary"]
numeric = [p for p in analysis_prompts if p.get("task_type", "binary") == "numeric"]

first_id = analysis_prompts[0].get("prompt_id", "?")
last_id = analysis_prompts[-1].get("prompt_id", "?")
print(
    f"Shard: rows [{START_PROMPT_ROW} … end] ({len(analysis_prompts)} prompts) "
    f"from {_n_full} in file — first={first_id}, last={last_id}"
)
print(f"  Binary : {len(binary)}")
print(f"    True : {sum(1 for p in binary if p['label'])}")
print(f"    False: {sum(1 for p in binary if not p['label'])}")
print(f"  Numeric: {len(numeric)}")
if numeric:
    print(f"    Targets: {sorted(set(p['label_token'] for p in numeric))}")
else:
    print("    Targets: []")
# Out:
# Shard: rows [160 … end] (141 prompts) from 300 in file — first=tri_v2_160, last=tri_v2_300
#   Binary : 128
#     True : 62
#     False: 66
#   Numeric: 13
#     Targets: ['2', '3', '5', '6', '7', '8', '9']

# %% [markdown]
# ## 3 — Load model

# %%
from circuit_tracer import ReplacementModel

model = ReplacementModel.from_pretrained(
    MODEL_NAME,
    TRANSCODER_NAME,
    dtype=torch.bfloat16,
    backend="transformerlens",
    device=device,
    lazy_encoder=True,
    lazy_decoder=True,
)
tokenizer = model.tokenizer

# Verify token IDs match constants
id_true  = tokenizer.encode(TOKEN_TRUE,  add_special_tokens=False)[-1]
id_false = tokenizer.encode(TOKEN_FALSE, add_special_tokens=False)[-1]
assert id_true  == VOCAB_ID_TRUE,  f"TOKEN_TRUE id mismatch: {id_true} != {VOCAB_ID_TRUE}"
assert id_false == VOCAB_ID_FALSE, f"TOKEN_FALSE id mismatch: {id_false} != {VOCAB_ID_FALSE}"
print(f"Token IDs verified: True={id_true}, False={id_false}")
# Out:
# /workspace/venvs/ct/lib/python3.11/site-packages/transformers/utils/hub.py:110: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loaded pretrained model google/gemma-2-2b into HookedTransformer
# Token IDs verified: True=5569, False=7662

# %% [markdown]
# ## 4 — First-token accuracy check (pre-attribution)
#
# Runs on **this notebook’s shard only** (prompts ≥ row 160).
#
# Quick sanity check: does the base model's top-1 token match the expected next token?
# For binary prompts this is True/False accuracy; for numeric prompts this is exact token match.

# %%
overall_correct = 0

binary_correct = 0
binary_total = 0
correct_true = 0
total_true = 0
correct_false = 0
total_false = 0

numeric_correct = 0
numeric_total = 0

# Keep per-prompt predictions in memory for downstream inspection/export.
first_token_predictions = []

progress_every = 10
acc_t0 = time.time()

with torch.inference_mode():
    for idx, entry in enumerate(analysis_prompts, start=1):
        # ReplacementModel (TransformerLens backend) does not expose .model;
        # use the no-op intervention path to get baseline logits.
        logits, _ = model.feature_intervention(entry["prompt"], [])
        last_logit = logits.squeeze(0)[-1, :]
        pred_id = int(last_logit.argmax().item())
        pred_token = tokenizer.decode([pred_id])

        task_type = entry.get("task_type", "binary")
        if task_type == "binary":
            label_id = VOCAB_ID_TRUE if entry["label"] else VOCAB_ID_FALSE
            expected_response = TOKEN_TRUE if entry["label"] else TOKEN_FALSE
            binary_total += 1
            is_correct = (pred_id == label_id)
            if is_correct:
                binary_correct += 1
                overall_correct += 1
            if entry["label"]:
                total_true += 1
                if pred_id == VOCAB_ID_TRUE:
                    correct_true += 1
            else:
                total_false += 1
                if pred_id == VOCAB_ID_FALSE:
                    correct_false += 1
        else:
            # Robust handling: if label_token is multi-token (e.g. ' 9'),
            # fallback to stripped variant (e.g. '9') when single-token.
            raw_label = entry["label_token"]
            label_ids = tokenizer.encode(raw_label, add_special_tokens=False)
            expected_response = raw_label
            if len(label_ids) != 1:
                alt = raw_label.lstrip()
                alt_ids = tokenizer.encode(alt, add_special_tokens=False)
                if len(alt_ids) == 1:
                    label_ids = alt_ids
                    expected_response = alt
                else:
                    raise ValueError(
                        f"Numeric label token must resolve to a single token, got {raw_label!r} -> {label_ids}, alt {alt!r} -> {alt_ids}"
                    )
            label_id = int(label_ids[0])
            numeric_total += 1
            is_correct = (pred_id == label_id)
            if is_correct:
                numeric_correct += 1
                overall_correct += 1

        first_token_predictions.append({
            "prompt_id": entry["prompt_id"],
            "task_type": task_type,
            "expected_response": expected_response,
            "argmax_response": pred_token,
            "expected_token_id": label_id,
            "argmax_token_id": pred_id,
            "is_correct": is_correct,
        })

        if idx % progress_every == 0 or idx == len(analysis_prompts):
            elapsed = max(time.time() - acc_t0, 1e-9)
            speed = idx / elapsed
            eta = (len(analysis_prompts) - idx) / speed if speed > 0 else float("inf")
            print(
                f"[accuracy progress] {idx}/{len(analysis_prompts)} "
                f"({idx/len(analysis_prompts):.0%}) | "
                f"running overall={overall_correct/max(idx,1):.1%} | "
                f"{speed:.2f} prompts/s | ETA {eta:.1f}s"
            )

n = len(analysis_prompts)
print("Base model first-token accuracy on this shard:")
print(f"  Overall : {overall_correct}/{n} = {overall_correct/n:.1%}")
if binary_total:
    print(f"  Binary  : {binary_correct}/{binary_total} = {binary_correct/binary_total:.1%}")
    print(f"    True  : {correct_true}/{total_true} = {correct_true/max(total_true,1):.1%}")
    print(f"    False : {correct_false}/{total_false} = {correct_false/max(total_false,1):.1%}")
if numeric_total:
    print(f"  Numeric : {numeric_correct}/{numeric_total} = {numeric_correct/numeric_total:.1%}")

if overall_correct / n > 0.80:
    print()
    print("NOTE: First-token accuracy >80%. Interpretability gains may appear smaller.")

print()
print(f"Stored per-prompt predictions in memory: first_token_predictions (n={len(first_token_predictions)})")
print("Preview (first 5):")
for row in first_token_predictions[:5]:
    print(
        f"  {row['prompt_id']}: expected={row['expected_response']!r} "
        f"argmax={row['argmax_response']!r} correct={row['is_correct']}"
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      19 with torch.inference_mode():
#      20     for idx, entry in enumerate(analysis_prompts, start=1):
#      21         # ReplacementModel (TransformerLens backend) does not expose .model;
#      22         # use the no-op intervention path to get baseline logits.
# ---> 23         logits, _ = model.feature_intervention(entry["prompt"], [])
#      24         last_logit = logits.squeeze(0)[-1, :]
#      25         pred_id = int(last_logit.argmax().item())
#      26         pred_token = tokenizer.decode([pred_id])
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /workspace/thesis_circuit_breaker/circuit_tracer/replacement_model/replacement_model_transformerlens.py:804, in TransformerLensReplacementModel.feature_intervention(self, inputs, interventions, constrained_layers, freeze_attention, apply_activation_function, sparse, return_activations)
#     793 hooks, _, activation_cache = self._get_feature_intervention_hooks(
#     794     inputs,
#     795     interventions,
#    (...)    800     return_activations=return_activations,
#     801 )
#     803 with self.hooks(hooks):  # type: ignore
# --> 804     logits = self(inputs)
#     806 activation_cache = torch.stack(activation_cache) if return_activations else None
#     808 return logits, activation_cache
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:632, in HookedTransformer.forward(self, input, return_type, loss_per_token, prepend_bos, padding_side, start_at_layer, tokens, shortformer_pos_embed, attention_mask, stop_at_layer, past_kv_cache)
#     627     if shortformer_pos_embed is not None:
#     628         shortformer_pos_embed = shortformer_pos_embed.to(
#     629             get_device_for_block_index(i, self.cfg)
#     630         )
# --> 632     residual = block(
#     633         residual,
#     634         # Cache contains a list of TransformerLensKeyValueCache objects, one for each
#     635         # block
#     636         past_kv_cache_entry=past_kv_cache[i] if past_kv_cache is not None else None,
#     637         shortformer_pos_embed=shortformer_pos_embed,
#     638         attention_mask=attention_mask,
#     639     )  # [batch, pos, d_model]
#     641 if stop_at_layer is not None:
#     642     # When we stop at an early layer, we end here rather than doing further computation
#     643     return residual
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/transformer_lens/components/transformer_block.py:203, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry, attention_mask)
#     201     mlp_out = self.ln2(mlp_out)
#     202 else:
# --> 203     normalized_resid_mid = self.ln2(mlp_in)
#     204     mlp_out = self.apply_mlp(normalized_resid_mid)
#     205 resid_post = self.hook_resid_post(resid_mid + mlp_out)  # [batch, pos, d_model]
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/transformer_lens/components/rms_norm.py:50, in RMSNorm.forward(self, x)
#      46     x = x.to(torch.float32)
#      47 scale: Float[torch.Tensor, "batch pos 1"] = self.hook_scale(
#      48     (x.pow(2).mean(-1, keepdim=True) + self.eps).sqrt()
#      49 )
# ---> 50 x = self.hook_normalized(x / scale).to(self.cfg.dtype)  # [batch, pos, length]
#      52 if x.device != self.w.device:
#      53     self.to(x.device)
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/nn/modules/module.py:1806, in Module._call_impl.<locals>.inner()
#    1804     hook_result = hook(self, args, kwargs, result)
#    1805 else:
# -> 1806     hook_result = hook(self, args, result)
#    1808 if hook_result is not None:
#    1809     result = hook_result
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/transformer_lens/hook_points.py:226, in HookPoint.add_hook.<locals>.full_hook(module, module_input, module_output)
#     223             module_output = hook_result
#     224 else:
#     225     # Call the hook once with the canonical name (self)
# --> 226     hook_result = hook(module_output, hook=self)
#     228 # Apply output reversion if hook_conversion exists and hook returned a value
#     229 if hook_result is not None and self.hook_conversion is not None:
#
# File /workspace/thesis_circuit_breaker/circuit_tracer/replacement_model/replacement_model_transformerlens.py:303, in TransformerLensReplacementModel._get_activation_caching_hooks.<locals>.cache_activations(acts, hook, layer)
#     301 def cache_activations(acts, hook, layer):
#     302     transcoder_acts = (
# --> 303         self.transcoders.encode_layer(
#     304             acts, layer, apply_activation_function=apply_activation_function
#     305         )
#     306         .detach()
#     307         .squeeze(0)
#     308     )
#     310     if not append:
#     311         transcoder_acts[self.zero_positions] = 0
#
# File /workspace/thesis_circuit_breaker/circuit_tracer/transcoder/single_layer_transcoder.py:392, in TranscoderSet.encode_layer(self, x, layer_id, apply_activation_function)
#     391 def encode_layer(self, x, layer_id, apply_activation_function=True):
# --> 392     return self.transcoders[layer_id].encode(
#     393         x, apply_activation_function=apply_activation_function
#     394     )
#
# File /workspace/thesis_circuit_breaker/circuit_tracer/transcoder/single_layer_transcoder.py:127, in SingleLayerTranscoder.encode(self, input_acts, apply_activation_function)
#     126 def encode(self, input_acts, apply_activation_function: bool = True):
# --> 127     W_enc = self.W_enc
#     128     pre_acts = F.linear(input_acts.to(W_enc.dtype), W_enc, self.b_enc)
#     129     if not apply_activation_function:
#
# File /workspace/thesis_circuit_breaker/circuit_tracer/transcoder/single_layer_transcoder.py:102, in SingleLayerTranscoder.__getattr__(self, name)
#      99 """Dynamically load weights when accessed if lazy loading is enabled."""
#     101 if name == "W_enc" and self.lazy_encoder and self.transcoder_path is not None:
# --> 102     with safe_open(
#     103         self.transcoder_path, framework="pt", device=safetensors_mmap_device(self.device)
#     104     ) as f:
#     105         return f.get_tensor("W_enc").to(device=self.device, dtype=self.dtype)
#     106 elif name == "W_dec" and self.lazy_decoder and self.transcoder_path is not None:
#
# File /workspace/venvs/ct/lib/python3.11/site-packages/torch/storage.py:417, in _StorageBase.untyped(self)
#     414     else:
#     415         return cls._new_using_fd_cpu(size)
# --> 417 def untyped(self):
#     418     return self
#     420 def byteswap(self, dtype):
#
# KeyboardInterrupt:

# %% [markdown]
# This is interesting, and may cause some trouble. The " 9" is tokenized to two, so we try to get the "9" token prediction. For the numeric, it appears that the most likely first token was always " " whitespace.

# %%
import pandas as pd
first_token_predictions_df = pd.DataFrame(first_token_predictions)
first_token_predictions_df[first_token_predictions_df['task_type'] == 'numeric'].head()
# Out:
#      prompt_id task_type expected_response argmax_response  expected_token_id  \
# 8   tri_v2_009   numeric                 6            \n\n             235318
# 9   tri_v2_010   numeric                 2                             235284
# 23  tri_v2_024   numeric                 3                             235304
# 32  tri_v2_033   numeric                 8            \n\n             235321
# 43  tri_v2_044   numeric                 2            \n\n             235284
#
#     argmax_token_id  is_correct
# 8               109       False
# 9            235248       False
# 23           235248       False
# 32              109       False
# 43              109       False

# %% [markdown]
# ## 5 — Attribution + stats (coupled, storage-safe)
#
# Runs attribution for each prompt and computes stats **immediately in one pass** —
# graph objects are discarded after stats are extracted (no full graph persisted to disk).
#
# **Artifact policy (configured by `N_FULL_GRAPH`):**
# - First `N_FULL_GRAPH` prompts: save `.pt` + frontend JSON for inspection/figures.
# - All prompts in this shard: compute and append stats to `stats_base_v2_from160.json`.
# - Remaining prompts: stats-only, no large graph files written.
#
# Resume support: prompts already in `stats_base_v2_from160.json` (this notebook) are skipped entirely.

# %%
import sys, importlib
sys.modules.pop("utils.graph_statistics", None)
import utils.graph_statistics as gs
importlib.reload(gs)

from circuit_tracer import attribute
from circuit_tracer.utils import create_graph_files
from utils.graph_statistics import compute_statistics, load_statistics, append_statistic

# Number of prompts for which full graph artifacts (.pt + JSON) are kept.
# All others get stats-only extraction (no large disk writes).
# Shard pod: default 0 (full .pt+JSON is slow); raise if you want full artifacts for first N of *this* shard.
N_FULL_GRAPH = 0

def _resolve_attr_targets(entry: dict) -> list[str]:
    task_type = entry.get("task_type", "binary")
    if task_type == "binary":
        return [TOKEN_TRUE, TOKEN_FALSE]
    raw_label = entry["label_token"]
    ids_raw = tokenizer.encode(raw_label, add_special_tokens=False)
    if len(ids_raw) == 1:
        return [raw_label]
    alt = raw_label.lstrip()
    ids_alt = tokenizer.encode(alt, add_special_tokens=False)
    if len(ids_alt) == 1:
        return [alt]
    raise ValueError(
        f"Numeric attribution target must be single-token, "
        f"got {raw_label!r}->{ids_raw}, alt {alt!r}->{ids_alt}"
    )

def _graph_pt_path(prompt_id: str) -> Path:
    return GRAPHS_DIR / prompt_id / f"{prompt_id}.pt"

print(f"N_FULL_GRAPH     : {N_FULL_GRAPH}  (full artifacts for first {N_FULL_GRAPH} prompts)")
print(f"Module file      : {gs.__file__}")
print(f"Robust load_stat : {'if not raw.strip():' in Path(gs.__file__).read_text()}")
# Out:
# N_FULL_GRAPH     : 0  (full artifacts for first 0 prompts)
# Module file      : /workspace/thesis_circuit_breaker/my_work/utils/graph_statistics.py
# Robust load_stat : True

# %%
# ── Resume: skip only successfully-attributed prompts ─────────────────────────
# Prompts where attribution_succeeded is False are retried on resume.
done_ids: set[str] = set()
existing_stats = load_statistics(STATS_FILE)
done_ids = {e["prompt_id"] for e in existing_stats if e.get("attribution_succeeded")}
n_failed_prev = sum(1 for e in existing_stats if not e.get("attribution_succeeded"))
print(f"Already done   : {len(done_ids)} prompts (succeeded)")
print(f"Previously failed: {n_failed_prev} (will retry)")

remaining = [p for p in analysis_prompts if p["prompt_id"] not in done_ids]
print(f"Remaining    : {len(remaining)} prompts")

# Full artifacts are saved only for the first N_FULL_GRAPH prompts (by dataset order).
# Determine which prompt IDs qualify, regardless of what is already done.
full_artifact_ids = {p["prompt_id"] for p in analysis_prompts[:N_FULL_GRAPH]}
print(f"Full-artifact set: {sorted(full_artifact_ids)}")
# Out:
# Already done   : 0 prompts (succeeded)
# Previously failed: 0 (will retry)
# Remaining    : 141 prompts
# Full-artifact set: []

# %%
import gc

# ── Coupled attribution + stats loop ──────────────────────────────────────────
t0 = time.time()
n_success = 0
n_fail = 0
progress_every = 5

for i, entry in enumerate(remaining, start=1):
    pid = entry["prompt_id"]
    task_type = entry.get("task_type", "binary")
    save_full = pid in full_artifact_ids
    print(f"[{i}/{len(remaining)}] {pid} ({task_type})"
          f"{' [full artifact]' if save_full else ''} ...", end=" ", flush=True)

    try:
        graph = attribute(
            prompt=entry["prompt"],
            model=model,
            attribution_targets=_resolve_attr_targets(entry),
            **ATTR_KWARGS,
        )

        # Compute stats immediately — before any optional disk I/O.
        stat = compute_statistics(graph, entry, phase=PHASE)
        append_statistic(stat, STATS_FILE)
        n_success += 1

        # Full artifact save for inspection subset only.
        if save_full:
            graph_out = GRAPHS_DIR / pid
            graph_out.mkdir(parents=True, exist_ok=True)
            graph.to_pt(str(_graph_pt_path(pid)))
            create_graph_files(graph, slug=pid, output_path=str(graph_out))

        # Discard large graph tensor, then aggressively free CUDA memory to
        # prevent allocator fragmentation across 300 sequential attribution calls.
        del graph
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.synchronize()
            torch.cuda.empty_cache()
            torch.cuda.ipc_collect()

        density = stat.get("edge_density")
        t20 = stat.get("topk20") or {}
        ls = stat.get("layer_stats") or {}
        print(
            f"OK  n_active={stat.get('n_active_features')}"
            + (f"  density={density:.4f}" if density is not None else "  density=N/A")
            + (f"  topk20={t20.get('score_total'):.3f}" if t20.get('score_total') is not None else "")
            + (f"  ent={ls.get('entropy_bits'):.2f}b" if ls.get('entropy_bits') is not None else "")
            + (" [saved .pt+JSON]" if save_full else "")
        )

    except Exception as exc:
        # Failed rows are NOT added to done_ids so resume will retry them.
        stat = {
            "prompt_id": pid,
            "phase": PHASE,
            "task_type": task_type,
            "family": entry.get("family"),
            "tail": entry.get("tail"),
            "label": entry["label"],
            "label_token": entry["label_token"],
            "template_id": entry.get("template_id"),
            "attribution_succeeded": False,
            "_error": str(exc),
        }
        append_statistic(stat, STATS_FILE)
        n_fail += 1
        print(f"FAIL {exc}")
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    if i % progress_every == 0 or i == len(remaining):
        elapsed = max(time.time() - t0, 1e-9)
        speed = i / elapsed
        eta = (len(remaining) - i) / speed if speed > 0 else float("inf")
        print(
            f"[progress] {i}/{len(remaining)} ({i/len(remaining):.0%}) | "
            f"success={n_success/max(i,1):.1%} | "
            f"{speed:.3f} prompts/s | ETA {eta/60:.1f} min"
        )

print()
print(f"Done. Elapsed: {time.time() - t0:.0f}s")
print(f"  Successes : {n_success}")
print(f"  Failures  : {n_fail}")
# Out:
# [1/141] tri_v2_160 (numeric) ... OK  n_active=30587  density=0.1189  topk20=0.000  ent=4.21b
# [2/141] tri_v2_161 (binary) ... OK  n_active=19233  density=0.1298  topk20=0.002  ent=4.29b
# [3/141] tri_v2_162 (binary) ... OK  n_active=26248  density=0.1229  topk20=0.001  ent=4.24b
# [4/141] tri_v2_163 (binary) ... OK  n_active=17808  density=0.1307  topk20=0.001  ent=4.29b
# [5/141] tri_v2_164 (numeric) ... OK  n_active=28982  density=0.1180  topk20=0.000  ent=4.19b
# [progress] 5/141 (4%) | success=100.0% | 0.012 prompts/s | ETA 186.9 min
# [6/141] tri_v2_165 (numeric) ... OK  n_active=29261  density=0.1149  topk20=0.000  ent=4.20b
# [7/141] tri_v2_166 (binary) ... OK  n_active=19690  density=0.1176  topk20=0.003  ent=4.24b
# [8/141] tri_v2_167 (binary) ... OK  n_active=23324  density=0.1255  topk20=0.021  ent=4.21b
# [9/141] tri_v2_168 (binary) ... OK  n_active=19412  density=0.1182  topk20=0.001  ent=4.27b
# [10/141] tri_v2_169 (binary) ... OK  n_active=32217  density=0.1132  topk20=0.001  ent=4.19b
# [progress] 10/141 (7%) | success=100.0% | 0.012 prompts/s | ETA 180.6 min
# [11/141] tri_v2_170 (binary) ... OK  n_active=27598  density=0.1159  topk20=0.000  ent=4.22b
# [12/141] tri_v2_171 (numeric) ... OK  n_active=28991  density=0.1166  topk20=0.000  ent=4.20b
# [13/141] tri_v2_172 (binary) ... OK  n_active=17294  density=0.1245  topk20=0.077  ent=4.30b
# [14/141] tri_v2_173 (binary) ... OK  n_active=30435  density=0.1139  topk20=0.001  ent=4.20b
# [15/141] tri_v2_174 (binary) ... OK  n_active=19216  density=0.1187  topk20=0.002  ent=4.24b
# [progress] 15/141 (11%) | success=100.0% | 0.012 prompts/s | ETA 174.2 min
# [16/141] tri_v2_175 (binary) ... OK  n_active=23439  density=0.1245  topk20=0.025  ent=4.21b
# [17/141] tri_v2_176 (binary) ... OK  n_active=21545  density=0.1233  topk20=0.001  ent=4.27b
# [18/141] tri_v2_177 (binary) ... OK  n_active=29249  density=0.1132  topk20=0.001  ent=4.20b
# [19/141] tri_v2_178 (numeric) ... OK  n_active=28744  density=0.1172  topk20=0.000  ent=4.20b
# [20/141] tri_v2_179 (binary) ... OK  n_active=16474  density=0.1303  topk20=0.002  ent=4.28b
# [progress] 20/141 (14%) | success=100.0% | 0.012 prompts/s | ETA 167.0 min
# [21/141] tri_v2_180 (binary) ... OK  n_active=16545  density=0.1248  topk20=0.084  ent=4.29b
# [22/141] tri_v2_181 (binary) ... OK  n_active=25869  density=0.1199  topk20=0.001  ent=4.24b
# [23/141] tri_v2_182 (binary) ... OK  n_active=27683  density=0.1215  topk20=0.001  ent=4.25b
# [24/141] tri_v2_183 (binary) ... OK  n_active=28709  density=0.1231  topk20=0.001  ent=4.24b
# [25/141] tri_v2_184 (binary) ... OK  n_active=17620  density=0.1293  topk20=0.084  ent=4.30b
# [progress] 25/141 (18%) | success=100.0% | 0.012 prompts/s | ETA 160.4 min
# [26/141] tri_v2_185 (numeric) ... OK  n_active=28744  density=0.1172  topk20=0.000  ent=4.20b
# [27/141] tri_v2_186 (binary) ... OK  n_active=15389  density=0.1242  topk20=0.025  ent=4.28b
# [28/141] tri_v2_187 (binary) ... OK  n_active=17483  density=0.1216  topk20=0.002  ent=4.29b
# [29/141] tri_v2_188 (binary) ... OK  n_active=18609  density=0.1102  topk20=0.032  ent=4.27b
# [30/141] tri_v2_189 (binary) ... OK  n_active=32896  density=0.1127  topk20=0.001  ent=4.19b
# [progress] 30/141 (21%) | success=100.0% | 0.012 prompts/s | ETA 153.0 min
# [31/141] tri_v2_190 (numeric) ... OK  n_active=28916  density=0.1185  topk20=0.000  ent=4.20b
# [32/141] tri_v2_191 (binary) ... OK  n_active=18077  density=0.1260  topk20=0.005  ent=4.29b
# [33/141] tri_v2_192 (binary) ... OK  n_active=23898  density=0.1188  topk20=0.008  ent=4.21b
# [34/141] tri_v2_193 (binary) ... OK  n_active=18643  density=0.1268  topk20=0.006  ent=4.30b
# [35/141] tri_v2_194 (binary) ... OK  n_active=24526  density=0.1192  topk20=0.000  ent=4.24b
# [progress] 35/141 (25%) | success=100.0% | 0.012 prompts/s | ETA 146.0 min
# [36/141] tri_v2_195 (binary) ... OK  n_active=31740  density=0.1142  topk20=0.001  ent=4.20b
# [37/141] tri_v2_196 (binary) ... OK  n_active=28709  density=0.1230  topk20=0.001  ent=4.24b
# [38/141] tri_v2_197 (binary) ... OK  n_active=19460  density=0.1189  topk20=0.001  ent=4.27b
# [39/141] tri_v2_198 (binary) ... OK  n_active=26004  density=0.1189  topk20=0.001  ent=4.24b
# [40/141] tri_v2_199 (binary) ... OK  n_active=29269  density=0.1165  topk20=0.000  ent=4.25b
# [progress] 40/141 (28%) | success=100.0% | 0.012 prompts/s | ETA 139.7 min
# [41/141] tri_v2_200 (binary) ... OK  n_active=18573  density=0.1121  topk20=0.039  ent=4.23b
# [42/141] tri_v2_201 (binary) ... OK  n_active=23526  density=0.1242  topk20=0.029  ent=4.21b
# [43/141] tri_v2_202 (binary) ... OK  n_active=20084  density=0.1188  topk20=0.013  ent=4.24b
# [44/141] tri_v2_203 (binary) ... OK  n_active=28075  density=0.1169  topk20=0.000  ent=4.24b
# [45/141] tri_v2_204 (binary) ... OK  n_active=16772  density=0.1258  topk20=0.001  ent=4.27b
# [progress] 45/141 (32%) | success=100.0% | 0.012 prompts/s | ETA 132.5 min
# [46/141] tri_v2_205 (binary) ... OK  n_active=20235  density=0.1167  topk20=0.001  ent=4.27b
# [47/141] tri_v2_206 (numeric) ... OK  n_active=28744  density=0.1172  topk20=0.000  ent=4.20b
# [48/141] tri_v2_207 (binary) ... OK  n_active=28660  density=0.1165  topk20=0.000  ent=4.25b
# [49/141] tri_v2_208 (binary) ... OK  n_active=15553  density=0.1243  topk20=0.027  ent=4.28b
# [50/141] tri_v2_209 (binary) ... OK  n_active=26447  density=0.1215  topk20=0.001  ent=4.24b
# [progress] 50/141 (35%) | success=100.0% | 0.012 prompts/s | ETA 125.8 min
# [51/141] tri_v2_210 (binary) ... OK  n_active=24559  density=0.1189  topk20=0.000  ent=4.24b
# [52/141] tri_v2_211 (binary) ... OK  n_active=21799  density=0.1189  topk20=0.000  ent=4.25b
# [53/141] tri_v2_212 (binary) ... OK  n_active=20532  density=0.1092  topk20=0.033  ent=4.27b
# [54/141] tri_v2_213 (binary) ... OK  n_active=20828  density=0.1217  topk20=0.000  ent=4.25b
# [55/141] tri_v2_214 (binary) ... OK  n_active=21134  density=0.1325  topk20=0.032  ent=4.23b
# [progress] 55/141 (39%) | success=100.0% | 0.012 prompts/s | ETA 118.7 min
# [56/141] tri_v2_215 (binary) ... OK  n_active=17402  density=0.1259  topk20=0.005  ent=4.29b
# [57/141] tri_v2_216 (binary) ... OK  n_active=17772  density=0.1285  topk20=0.081  ent=4.28b
# [58/141] tri_v2_217 (binary) ... OK  n_active=16290  density=0.1231  topk20=0.022  ent=4.28b
# [59/141] tri_v2_218 (binary) ... OK  n_active=21178  density=0.1186  topk20=0.001  ent=4.25b
# [60/141] tri_v2_219 (binary) ... OK  n_active=21213  density=0.1206  topk20=0.059  ent=4.27b
# [progress] 60/141 (43%) | success=100.0% | 0.012 prompts/s | ETA 111.1 min
# [61/141] tri_v2_220 (numeric) ... OK  n_active=28912  density=0.1188  topk20=0.000  ent=4.20b
# [62/141] tri_v2_221 (binary) ... OK  n_active=24743  density=0.1185  topk20=0.001  ent=4.23b
# [63/141] tri_v2_222 (binary) ... OK  n_active=24710  density=0.1229  topk20=0.001  ent=4.23b
# [64/141] tri_v2_223 (binary) ... OK  n_active=20202  density=0.1220  topk20=0.001  ent=4.26b
# [65/141] tri_v2_224 (binary) ... OK  n_active=24914  density=0.1241  topk20=0.001  ent=4.24b
# [progress] 65/141 (46%) | success=100.0% | 0.012 prompts/s | ETA 104.4 min
# [66/141] tri_v2_225 (binary) ... OK  n_active=28295  density=0.1215  topk20=0.001  ent=4.25b
# [67/141] tri_v2_226 (binary) ... OK  n_active=16249  density=0.1299  topk20=0.091  ent=4.29b
# [68/141] tri_v2_227 (binary) ... OK  n_active=20955  density=0.1180  topk20=0.000  ent=4.25b
# [69/141] tri_v2_228 (binary) ... OK  n_active=16315  density=0.1296  topk20=0.001  ent=4.27b
# [70/141] tri_v2_229 (binary) ... OK  n_active=16445  density=0.1300  topk20=0.002  ent=4.29b
# [progress] 70/141 (50%) | success=100.0% | 0.012 prompts/s | ETA 97.4 min
# [71/141] tri_v2_230 (binary) ... OK  n_active=16403  density=0.1251  topk20=0.001  ent=4.28b
# [72/141] tri_v2_231 (binary) ... OK  n_active=19404  density=0.1151  topk20=0.001  ent=4.24b
# [73/141] tri_v2_232 (binary) ... OK  n_active=29059  density=0.1190  topk20=0.001  ent=4.22b
# [74/141] tri_v2_233 (binary) ... OK  n_active=16373  density=0.1246  topk20=0.088  ent=4.29b
# [75/141] tri_v2_234 (binary) ... OK  n_active=17657  density=0.1259  topk20=0.036  ent=4.29b
# [progress] 75/141 (53%) | success=100.0% | 0.012 prompts/s | ETA 90.0 min
# [76/141] tri_v2_235 (binary) ... OK  n_active=21250  density=0.1307  topk20=0.035  ent=4.23b
# [77/141] tri_v2_236 (binary) ... OK  n_active=17085  density=0.1292  topk20=0.002  ent=4.29b
# [78/141] tri_v2_237 (binary) ... OK  n_active=18357  density=0.1137  topk20=0.046  ent=4.23b
# [79/141] tri_v2_238 (binary) ... OK  n_active=24616  density=0.1191  topk20=0.000  ent=4.24b
# [80/141] tri_v2_239 (binary) ... OK  n_active=27683  density=0.1215  topk20=0.001  ent=4.25b
# [progress] 80/141 (57%) | success=100.0% | 0.012 prompts/s | ETA 82.6 min
# [81/141] tri_v2_240 (binary) ... OK  n_active=20120  density=0.1219  topk20=0.001  ent=4.26b
# [82/141] tri_v2_241 (binary) ... OK  n_active=30452  density=0.1215  topk20=0.001  ent=4.24b
# [83/141] tri_v2_242 (binary) ... OK  n_active=23055  density=0.1270  topk20=0.036  ent=4.21b
# [84/141] tri_v2_243 (binary) ... OK  n_active=26933  density=0.1184  topk20=0.001  ent=4.26b
# [85/141] tri_v2_244 (binary) ... OK  n_active=19266  density=0.1168  topk20=0.001  ent=4.24b
# [progress] 85/141 (60%) | success=100.0% | 0.012 prompts/s | ETA 75.8 min
# [86/141] tri_v2_245 (binary) ... OK  n_active=27791  density=0.1204  topk20=0.001  ent=4.26b
# [87/141] tri_v2_246 (binary) ... OK  n_active=25058  density=0.1236  topk20=0.001  ent=4.23b
# [88/141] tri_v2_247 (binary) ... OK  n_active=17732  density=0.1299  topk20=0.001  ent=4.28b
# [89/141] tri_v2_248 (binary) ... OK  n_active=18753  density=0.1089  topk20=0.012  ent=4.27b
# [90/141] tri_v2_249 (binary) ... OK  n_active=15367  density=0.1227  topk20=0.026  ent=4.28b
# [progress] 90/141 (64%) | success=100.0% | 0.012 prompts/s | ETA 68.7 min
# [91/141] tri_v2_250 (binary) ... OK  n_active=24861  density=0.1248  topk20=0.001  ent=4.24b
# [92/141] tri_v2_251 (numeric) ... OK  n_active=28646  density=0.1171  topk20=0.000  ent=4.20b
# [93/141] tri_v2_252 (binary) ... OK  n_active=31599  density=0.1145  topk20=0.001  ent=4.20b
# [94/141] tri_v2_253 (binary) ... OK  n_active=18317  density=0.1174  topk20=0.070  ent=4.24b
# [95/141] tri_v2_254 (binary) ... OK  n_active=20443  density=0.1192  topk20=0.011  ent=4.24b
# [progress] 95/141 (67%) | success=100.0% | 0.012 prompts/s | ETA 62.0 min
# [96/141] tri_v2_255 (binary) ... OK  n_active=20025  density=0.1192  topk20=0.015  ent=4.24b
# [97/141] tri_v2_256 (binary) ... OK  n_active=26088  density=0.1199  topk20=0.000  ent=4.24b
# [98/141] tri_v2_257 (binary) ... OK  n_active=29584  density=0.1220  topk20=0.000  ent=4.23b
# [99/141] tri_v2_258 (binary) ... OK  n_active=29223  density=0.1219  topk20=0.001  ent=4.24b
# [100/141] tri_v2_259 (binary) ... OK  n_active=20519  density=0.1179  topk20=0.012  ent=4.22b
# [progress] 100/141 (71%) | success=100.0% | 0.012 prompts/s | ETA 55.2 min
# [101/141] tri_v2_260 (binary) ... OK  n_active=17027  density=0.1286  topk20=0.084  ent=4.29b
# [102/141] tri_v2_261 (binary) ... OK  n_active=19271  density=0.1108  topk20=0.034  ent=4.28b
# [103/141] tri_v2_262 (binary) ... OK  n_active=28565  density=0.1233  topk20=0.001  ent=4.23b
# [104/141] tri_v2_263 (binary) ... OK  n_active=17118  density=0.1296  topk20=0.076  ent=4.28b
# [105/141] tri_v2_264 (binary) ... OK  n_active=17679  density=0.1172  topk20=0.036  ent=4.30b
# [progress] 105/141 (74%) | success=100.0% | 0.012 prompts/s | ETA 48.3 min
# [106/141] tri_v2_265 (binary) ... OK  n_active=18753  density=0.1088  topk20=0.012  ent=4.27b
# [107/141] tri_v2_266 (numeric) ... OK  n_active=29272  density=0.1161  topk20=0.000  ent=4.20b
# [108/141] tri_v2_267 (binary) ... OK  n_active=27954  density=0.1184  topk20=0.000  ent=4.24b
# [109/141] tri_v2_268 (binary) ... OK  n_active=26482  density=0.1207  topk20=0.001  ent=4.26b
# [110/141] tri_v2_269 (binary) ... OK  n_active=15866  density=0.1265  topk20=0.051  ent=4.27b
# [progress] 110/141 (78%) | success=100.0% | 0.012 prompts/s | ETA 41.4 min
# [111/141] tri_v2_270 (binary) ... OK  n_active=21159  density=0.1189  topk20=0.008  ent=4.25b
# [112/141] tri_v2_271 (binary) ... OK  n_active=24616  density=0.1191  topk20=0.000  ent=4.24b
# [113/141] tri_v2_272 (numeric) ... OK  n_active=30594  density=0.1155  topk20=0.000  ent=4.21b
# [114/141] tri_v2_273 (binary) ... OK  n_active=19643  density=0.1195  topk20=0.001  ent=4.27b
# [115/141] tri_v2_274 (binary) ... OK  n_active=19543  density=0.1171  topk20=0.012  ent=4.23b
# [progress] 115/141 (82%) | success=100.0% | 0.012 prompts/s | ETA 34.8 min
# [116/141] tri_v2_275 (binary) ... OK  n_active=15707  density=0.1291  topk20=0.086  ent=4.28b
# [117/141] tri_v2_276 (binary) ... OK  n_active=19462  density=0.1169  topk20=0.001  ent=4.26b
# [118/141] tri_v2_277 (binary) ... OK  n_active=17316  density=0.1291  topk20=0.001  ent=4.28b
# [119/141] tri_v2_278 (binary) ... OK  n_active=20966  density=0.1174  topk20=0.007  ent=4.25b
# [120/141] tri_v2_279 (binary) ... OK  n_active=19958  density=0.1207  topk20=0.050  ent=4.26b
# [progress] 120/141 (85%) | success=100.0% | 0.012 prompts/s | ETA 28.1 min
# [121/141] tri_v2_280 (binary) ... OK  n_active=17140  density=0.1296  topk20=0.083  ent=4.29b
# [122/141] tri_v2_281 (binary) ... OK  n_active=18022  density=0.1258  topk20=0.005  ent=4.29b
# [123/141] tri_v2_282 (binary) ... OK  n_active=19613  density=0.1153  topk20=0.000  ent=4.26b
# [124/141] tri_v2_283 (binary) ... OK  n_active=16371  density=0.1230  topk20=0.092  ent=4.29b
# [125/141] tri_v2_284 (binary) ... OK  n_active=17939  density=0.1263  topk20=0.006  ent=4.30b
# [progress] 125/141 (89%) | success=100.0% | 0.012 prompts/s | ETA 21.4 min
# [126/141] tri_v2_285 (binary) ... OK  n_active=20853  density=0.1187  topk20=0.000  ent=4.24b
# [127/141] tri_v2_286 (binary) ... OK  n_active=24899  density=0.1228  topk20=0.001  ent=4.23b
# [128/141] tri_v2_287 (binary) ... OK  n_active=19489  density=0.1185  topk20=0.001  ent=4.27b
# [129/141] tri_v2_288 (binary) ... OK  n_active=20423  density=0.1192  topk20=0.001  ent=4.25b
# [130/141] tri_v2_289 (binary) ... OK  n_active=25972  density=0.1216  topk20=0.001  ent=4.25b
# [progress] 130/141 (92%) | success=100.0% | 0.012 prompts/s | ETA 14.7 min
# [131/141] tri_v2_290 (binary) ... OK  n_active=20829  density=0.1211  topk20=0.000  ent=4.27b
# [132/141] tri_v2_291 (binary) ... OK  n_active=20091  density=0.1231  topk20=0.001  ent=4.26b
# [133/141] tri_v2_292 (binary) ... OK  n_active=20860  density=0.1227  topk20=0.000  ent=4.25b
# [134/141] tri_v2_293 (binary) ... OK  n_active=18692  density=0.1114  topk20=0.027  ent=4.27b
# [135/141] tri_v2_294 (binary) ... OK  n_active=20830  density=0.1177  topk20=0.001  ent=4.28b
# [progress] 135/141 (96%) | success=100.0% | 0.012 prompts/s | ETA 8.0 min
# [136/141] tri_v2_295 (numeric) ... OK  n_active=28916  density=0.1185  topk20=0.000  ent=4.20b
# [137/141] tri_v2_296 (binary) ... OK  n_active=18292  density=0.1291  topk20=0.078  ent=4.30b
# [138/141] tri_v2_297 (binary) ... OK  n_active=19156  density=0.1282  topk20=0.001  ent=4.30b
# [139/141] tri_v2_298 (binary) ... OK  n_active=21815  density=0.1203  topk20=0.011  ent=4.23b
# [140/141] tri_v2_299 (binary) ... OK  n_active=19149  density=0.1173  topk20=0.001  ent=4.23b
# [progress] 140/141 (99%) | success=100.0% | 0.012 prompts/s | ETA 1.3 min
# [141/141] tri_v2_300 (binary) ... OK  n_active=17870  density=0.1289  topk20=0.001  ent=4.29b
# [progress] 141/141 (100%) | success=100.0% | 0.012 prompts/s | ETA 0.0 min
#
# Done. Elapsed: 11360s
#   Successes : 141
#   Failures  : 0

# %% [markdown]
# ## 6 — Summary and go/no-go check

# %%
from utils.graph_statistics import load_statistics, aggregate_statistics
import json

all_stats = load_statistics(STATS_FILE)
agg = aggregate_statistics(all_stats)

print(f"Total prompts in stats file : {agg['n_total']}")
print(f"Successfully attributed     : {agg['n_succeeded']}")
print(f"Success rate                : {agg['success_rate']:.1%}")
print()

# ── Legacy scalar block ────────────────────────────────────────────────────────
legacy_metrics = [
    'n_active_features', 'edge_density', 'mean_top50_score',
    'top10_over_top50', 'layer_entropy', 'mean_error_node_weight',
    'logit_gap',
]
print("── Legacy metrics ─────────────────────────────────────────────────────")
print(f"{'Metric':<32} {'Mean':>10} {'Std':>10} {'Median':>10} {'IQR':>10}")
print("-" * 76)
for m in legacy_metrics:
    v = agg.get(m)
    if v:
        print(f"{m:<32} {v['mean']:>10.4f} {v['std']:>10.4f} {v['median']:>10.4f} {v['iqr']:>10.4f}")
    else:
        print(f"{m:<32} {'N/A':>10}")

print()

# ── Supervisor layer_stats block ───────────────────────────────────────────────
print("── Supervisor: layer scalar summary ───────────────────────────────────")
print(f"{'Metric':<32} {'Mean':>10} {'Std':>10} {'Median':>10} {'IQR':>10}")
print("-" * 76)
for m in ['layer_stats_mean', 'layer_stats_std', 'layer_stats_median', 'layer_stats_entropy_bits']:
    v = agg.get(m)
    if v:
        print(f"{m:<32} {v['mean']:>10.4f} {v['std']:>10.4f} {v['median']:>10.4f} {v['iqr']:>10.4f}")
    else:
        print(f"{m:<32} {'N/A':>10}")

print()

# ── Supervisor topk20 scalars ──────────────────────────────────────────────────
print("── Supervisor: top-K=20 influence scalars ──────────────────────────────")
for m in ['topk20_score_total', 'topk20_score_gini']:
    v = agg.get(m)
    if v:
        print(f"{m:<32} mean={v['mean']:.4f}  std={v['std']:.4f}  IQR={v['iqr']:.4f}")
    else:
        print(f"{m:<32} N/A")

print()

# ── Supervisor: prune_curve summary (mean node/edge counts per threshold) ──────
pc = agg.get("prune_curve_agg")
if pc:
    print("── Supervisor: prune curve (mean across prompts) ───────────────────────")
    print(f"{'Threshold':>10} {'Mean nodes':>12} {'Mean edges':>12} {'Mean density':>14}")
    print("-" * 52)
    for t_str, vals in sorted(pc.items(), key=lambda x: float(x[0])):
        mn = vals["mean_n_nodes"]
        me = vals["mean_n_edges"]
        md = vals["mean_density"]
        print(
            f"{float(t_str):>10.2f} "
            f"{mn if mn is None else f'{mn:>12.1f}'} "
            f"{me if me is None else f'{me:>12.1f}'} "
            f"{md if md is None else f'{md:>14.6f}'}"
        )
    print()

# ── Go/no-go check ─────────────────────────────────────────────────────────────
sr = agg['success_rate']
if sr < 0.70:
    print("STOP: Success rate below 70%. Investigate prompt set before proceeding.")
elif sr < 0.85:
    print(f"NOTE: Success rate {sr:.1%} is below 85%. Proceed but flag as limitation.")
else:
    print(f"Success rate {sr:.1%} — OK to proceed to notebook 03.")
# Out:
# Total prompts in stats file : 141
# Successfully attributed     : 141
# Success rate                : 100.0%
#
# ── Legacy metrics ─────────────────────────────────────────────────────
# Metric                                 Mean        Std     Median        IQR
# ----------------------------------------------------------------------------
# n_active_features                22379.7376  4804.1844 20830.0000  8576.0000
# edge_density                         0.1209     0.0052     0.1203     0.0070
# mean_top50_score                     0.0004     0.0007     0.0000     0.0004
# top10_over_top50                     0.4097     0.0724     0.3816     0.1089
# layer_entropy                        2.2992     0.2622     2.3015     0.3895
# mean_error_node_weight               0.3063     0.0359     0.2926     0.0308
# logit_gap                           -0.3030     2.9792     0.9979     3.1293
#
# ── Supervisor: layer scalar summary ───────────────────────────────────
# Metric                                 Mean        Std     Median        IQR
# ----------------------------------------------------------------------------
# layer_stats_mean                     8.8430     0.2460     8.8239     0.3563
# layer_stats_std                      7.1964     0.0985     7.1835     0.1663
# layer_stats_median                   6.9504     0.2172     7.0000     0.0000
# layer_stats_entropy_bits             4.2501     0.0304     4.2480     0.0445
#
# ── Supervisor: top-K=20 influence scalars ──────────────────────────────
# topk20_score_total               mean=0.0143  std=0.0251  IQR=0.0126
# topk20_score_gini                mean=0.2404  std=0.0682  IQR=0.0922
#
# ── Supervisor: prune curve (mean across prompts) ───────────────────────
#  Threshold   Mean nodes   Mean edges   Mean density
# ----------------------------------------------------
#       0.50        362.3      20490.3       0.152694
#       0.60        787.0      96152.9       0.153417
#       0.70       1503.0     353353.7       0.155451
#       0.80       2708.4    1138636.6       0.154744
#       0.90       4776.8    3481441.4       0.152374
#       0.95       6386.8    6042907.6       0.147996
#       0.99       8177.3    9504195.6       0.142074
#
# Success rate 100.0% — OK to proceed to notebook 03.
