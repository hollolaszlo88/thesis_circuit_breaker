# %% [markdown]
# # 04e — Post-LoRA Attribution (L1 — General T/F)
#
# **Runs on RunPod GPU. Always start from a FRESH kernel.**
#
# Loads the merged LoRA checkpoint (`my_work/checkpoints/lora_l1_merged/`)
# produced by `04d_lora_l1_training.ipynb` and runs attribution on **every row** of the
# frozen probe set (`prompts_triangle_v2.jsonl`) — **binary and numeric** `task_type`
# slices, mirroring attribution targets from **`02`**.
#
# **Why a separate notebook?**  Training leaves ~12 GB of GPU memory that cannot
# be freed without a kernel restart (`empty_cache()` only releases the PyTorch
# cache, not memory held by the CUDA process).  Starting fresh gives the full
# 19–24 GB to Gemma-2-2B + transcoders + attribution.
#
# **Prerequisites:**
# - `04_lora_training_data.ipynb` run (probe JSONL exists)
# - `04d_lora_l1_training.ipynb` run through §7 (`lora_l1_merged/` exists)
#
# **Outputs:**
# - Pilot: `my_work/results/statistics/stats_lora_l1_pilot.json`
# - Full:  `my_work/results/statistics/stats_lora_l1.json`
#
# **Checkpointing:** Stats append after each prompt. Re-running §5 skips **`prompt_id`s** already succeeded in **`STATS_FILE`**.
#
# **Pilot to full:** **`RUN_FULL=True`** makes §5 copy successful pilot rows into the full stats file (instant, no GPU) so attribution is never paid twice; use **`stats_lora_l1.json`** in **`05`** with **`USE_PILOT=False`** when the sweep is finished.

# %% [markdown]
# ## 0 — Environment setup

# %%
import os
import sys
from pathlib import Path

# Must be set BEFORE torch is imported anywhere.
os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")

IN_RUNPOD = os.environ.get("RUNPOD_POD_ID") is not None

def _find_repo_root():
    start = Path.cwd().resolve()
    for directory in [start, *start.parents]:
        if (directory / "circuit_tracer" / "__init__.py").is_file():
            return directory
    workspace = Path("/workspace")
    if workspace.is_dir():
        for child in workspace.iterdir():
            if child.is_dir() and (child / "circuit_tracer" / "__init__.py").is_file():
                return child
    repo_override = os.environ.get("CT_REPO_DIR")
    if repo_override:
        p = Path(repo_override).expanduser().resolve()
        if (p / "circuit_tracer" / "__init__.py").is_file():
            return p
    return None

_root = _find_repo_root()
if _root is not None:
    if str(_root) not in sys.path:
        sys.path.insert(0, str(_root))
    _my_work = _root / "my_work"
    if str(_my_work) not in sys.path:
        sys.path.insert(0, str(_my_work))
    print(f"Repo root: {_root}")
else:
    print("WARNING: could not locate circuit_tracer repo. Set CT_REPO_DIR.")

try:
    from dotenv import load_dotenv
    if _root is not None and (_root / ".env").is_file():
        load_dotenv(_root / ".env")
except ImportError:
    pass

MY_WORK = _my_work if _root else Path(".").resolve()

if IN_RUNPOD:
    persistent_root = Path(os.environ.get("RUNPOD_PERSISTENT_ROOT", "/workspace")).resolve()
    hf_home = persistent_root / "hf"
    for key, path in {
        "HF_HOME": hf_home,
        "HUGGINGFACE_HUB_CACHE": hf_home / "hub",
        "TRANSFORMERS_CACHE": hf_home / "transformers",
    }.items():
        path.mkdir(parents=True, exist_ok=True)
        os.environ[key] = str(path)

STATS_DIR  = MY_WORK / "results" / "statistics"
GRAPHS_DIR = MY_WORK / "results" / "graphs_lora_l1"
STATS_DIR.mkdir(parents=True, exist_ok=True)
GRAPHS_DIR.mkdir(parents=True, exist_ok=True)

print(f"MY_WORK  : {MY_WORK}")
# Out:
# Repo root: /workspace/thesis_circuit_breaker
# MY_WORK  : /workspace/thesis_circuit_breaker/my_work

# %% [markdown]
# ## 1 — Constants

# %%
import json
import time
import gc
import traceback
import random

import torch

MODEL_NAME      = "google/gemma-2-2b"
TRANSCODER_NAME = "gemma"
TOKEN_TRUE      = " True"
TOKEN_FALSE     = " False"
VOCAB_ID_TRUE   = 5569
VOCAB_ID_FALSE  = 7662

ATTR_KWARGS = dict(
    batch_size=256,
    max_feature_nodes=8192,
    offload="disk",
    verbose=False,
)
PHASE = "lora_l1"

# Pilot vs full
# Start RUN_FULL=False for ~N_PILOT prompts. Set RUN_FULL=True to run everyone;
# §5 skips rows already saved and copies pilot successes into the full file (no rerun).
RUN_FULL = True
N_PILOT  = 40

MERGED_DIR       = MY_WORK / "checkpoints" / "lora_l1_merged"
PROBE_JSONL      = MY_WORK / "data" / "prompts_triangle_v2.jsonl"
PILOT_STATS_FILE = STATS_DIR / "stats_lora_l1_pilot.json"
FULL_STATS_FILE  = STATS_DIR / "stats_lora_l1.json"
STATS_FILE       = FULL_STATS_FILE if RUN_FULL else PILOT_STATS_FILE

assert MERGED_DIR.exists(), (
    f"Merged checkpoint not found: {MERGED_DIR}\n"
    "Run 04d_lora_l1_training.ipynb through §7 first."
)

device_str = "cuda" if torch.cuda.is_available() else "cpu"
device     = torch.device(device_str)

print(f"MERGED_DIR : {MERGED_DIR}")
print(f"STATS_FILE : {STATS_FILE}")
print(f"RUN_FULL   : {RUN_FULL}  (pilot N={N_PILOT})")
print(f"CUDA       : {torch.cuda.is_available()}", end="")
if torch.cuda.is_available():
    free, total = torch.cuda.mem_get_info()
    print(f"  |  Free VRAM: {free/1e9:.1f} GB / {total/1e9:.1f} GB")
else:
    print()
# Out:
# MERGED_DIR : /workspace/thesis_circuit_breaker/my_work/checkpoints/lora_l1_merged
# STATS_FILE : /workspace/thesis_circuit_breaker/my_work/results/statistics/stats_lora_l1.json
# RUN_FULL   : True  (pilot N=40)
# CUDA       : True  |  Free VRAM: 20.8 GB / 21.0 GB

# %% [markdown]
# ## 2 — Load merged model into ReplacementModel
#
# TransformerLens requires a registered `model_name`; pass the local merged
# weights via `hf_model=`.  We load `merged_hf` on CPU so that only one copy
# of Gemma-2-2B lives on the GPU (inside HookedTransformer) at any time.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from circuit_tracer import ReplacementModel

print("Loading merged weights on CPU ...")
merged_hf = AutoModelForCausalLM.from_pretrained(
    str(MERGED_DIR),
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    device_map="cpu",
).eval()

print("Building ReplacementModel (moves weights to GPU) ...")
ct_model = ReplacementModel.from_pretrained(
    MODEL_NAME,
    TRANSCODER_NAME,
    dtype=torch.bfloat16,
    backend="transformerlens",
    device=device,
    lazy_encoder=True,
    lazy_decoder=True,
    hf_model=merged_hf,
)

# Free the CPU copy immediately — HookedTransformer now holds the weights on GPU.
del merged_hf
gc.collect()

ct_tokenizer = ct_model.tokenizer

id_true  = ct_tokenizer.encode(TOKEN_TRUE,  add_special_tokens=False)[-1]
id_false = ct_tokenizer.encode(TOKEN_FALSE, add_special_tokens=False)[-1]
assert id_true  == VOCAB_ID_TRUE,  f"Token mismatch True:  {id_true}"
assert id_false == VOCAB_ID_FALSE, f"Token mismatch False: {id_false}"
print(f"ReplacementModel ready. Token IDs: True={id_true}, False={id_false}")
if torch.cuda.is_available():
    free, total = torch.cuda.mem_get_info()
    print(f"VRAM after load: {(total-free)/1e9:.1f} GB used / {total/1e9:.1f} GB total")
# Out:
# /workspace/venvs/ct/lib/python3.11/site-packages/transformers/utils/hub.py:110: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading merged weights on CPU ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Building ReplacementModel (moves weights to GPU) ...
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# Loaded pretrained model google/gemma-2-2b into HookedTransformer
# ReplacementModel ready. Token IDs: True=5569, False=7662
# VRAM after load: 8.6 GB used / 21.0 GB total

# %% [markdown]
# ## 3 — Load full probe set (binary + numeric) and optional pilot subset

# %%
from collections import Counter, defaultdict

def _resolve_attr_targets(entry: dict) -> list[str]:
    """Same logic as `02_baseline_attribution.ipynb` (single-token numeric targets)."""
    task_type = entry.get("task_type", "binary")
    if task_type == "binary":
        return [TOKEN_TRUE, TOKEN_FALSE]
    raw_label = entry["label_token"]
    ids_raw = ct_tokenizer.encode(raw_label, add_special_tokens=False)
    if len(ids_raw) == 1:
        return [raw_label]
    alt = raw_label.lstrip()
    ids_alt = ct_tokenizer.encode(alt, add_special_tokens=False)
    if len(ids_alt) == 1:
        return [alt]
    raise ValueError(
        f"Numeric attribution target must be single-token, "
        f"got {raw_label!r}->{ids_raw}, alt {alt!r}->{ids_alt}"
    )

all_probe = []
with open(PROBE_JSONL, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        all_probe.append(json.loads(line))

print(f"All probe prompts: {len(all_probe)}")
print("  by task_type:", dict(Counter(p.get("task_type", "binary") for p in all_probe)))

if RUN_FULL:
    probe_prompts = all_probe
    print(f"RUN_FULL=True: using all {len(probe_prompts)} prompts.")
else:
    strata: dict = defaultdict(list)
    for p in all_probe:
        key = (p.get("family", "?"), p.get("tail", "?"), str(p.get("label", "?")))
        strata[key].append(p)

    rng = random.Random(42)
    pilot = []
    per_stratum = max(1, N_PILOT // len(strata))
    for key, bucket in sorted(strata.items()):
        rng.shuffle(bucket)
        pilot.extend(bucket[:per_stratum])

    remaining_pool = [p for p in all_probe if p not in pilot]
    rng.shuffle(remaining_pool)
    while len(pilot) < N_PILOT and remaining_pool:
        pilot.append(remaining_pool.pop(0))

    probe_prompts = pilot[:N_PILOT]
    dist = Counter(
        (p.get("family", "?"), p.get("tail", "?"), str(p.get("label", "?")))
        for p in probe_prompts
    )
    print(f"Pilot subset: {len(probe_prompts)} prompts")
    for key, cnt in sorted(dist.items()):
        print(f"  {key}: {cnt}")
# Out:
# All probe prompts: 300
#   by task_type: {'binary': 270, 'numeric': 30}
# RUN_FULL=True: using all 300 prompts.

# %% [markdown]
# ## 4 — First-token accuracy (post-LoRA), binary + numeric

# %%
overall_correct = 0

binary_correct = 0
binary_total = 0
correct_true = 0
total_true = 0
correct_false = 0
total_false = 0

numeric_correct = 0
numeric_total = 0

predictions = []

with torch.inference_mode():
    for entry in probe_prompts:
        logits, _ = ct_model.feature_intervention(entry["prompt"], [])
        last_logit = logits.squeeze(0)[-1, :]
        pred_id = int(last_logit.argmax().item())
        pred_tok = ct_tokenizer.decode([pred_id])

        task_type = entry.get("task_type", "binary")
        if task_type == "binary":
            label_id = VOCAB_ID_TRUE if entry["label"] else VOCAB_ID_FALSE
            binary_total += 1
            is_ok = pred_id == label_id
            if is_ok:
                binary_correct += 1
                overall_correct += 1
            if entry["label"]:
                total_true += 1
                if pred_id == VOCAB_ID_TRUE:
                    correct_true += 1
            else:
                total_false += 1
                if pred_id == VOCAB_ID_FALSE:
                    correct_false += 1
        else:
            raw_label = entry["label_token"]
            label_ids = ct_tokenizer.encode(raw_label, add_special_tokens=False)
            if len(label_ids) != 1:
                alt = raw_label.lstrip()
                alt_ids = ct_tokenizer.encode(alt, add_special_tokens=False)
                if len(alt_ids) == 1:
                    label_ids = alt_ids
                else:
                    raise ValueError(
                        f"Numeric label_token must encode to single id, "
                        f"got {raw_label!r}->{label_ids}, alt {alt!r}->{alt_ids}"
                    )
            label_id = int(label_ids[0])
            numeric_total += 1
            is_ok = pred_id == label_id
            if is_ok:
                numeric_correct += 1
                overall_correct += 1

        predictions.append({
            "prompt_id": entry["prompt_id"],
            "task_type": task_type,
            "pred_token": pred_tok,
            "pred_id": pred_id,
            "is_correct": is_ok,
        })

n = len(probe_prompts)
print(f"Post-LoRA first-token accuracy (n={n}):")
print(f"  Overall : {overall_correct}/{n} = {overall_correct/n:.1%}")
if binary_total:
    print(f"  Binary  : {binary_correct}/{binary_total} = {binary_correct/binary_total:.1%}")
    if total_true:
        print(f"    True : {correct_true}/{total_true} = {correct_true/total_true:.1%}")
    if total_false:
        print(f"    False: {correct_false}/{total_false} = {correct_false/total_false:.1%}")
if numeric_total:
    print(f"  Numeric : {numeric_correct}/{numeric_total} = {numeric_correct/numeric_total:.1%}")
print("(Baseline notebook `02` uses the same split for comparison.)")
# Out:
# Post-LoRA first-token accuracy (n=300):
#   Overall : 175/300 = 58.3%
#   Binary  : 175/270 = 64.8%
#     True : 100/135 = 74.1%
#     False: 75/135 = 55.6%
#   Numeric : 0/30 = 0.0%
# (Baseline notebook `02` uses the same split for comparison.)

# %%
import pandas as pd

_csv_path = MY_WORK / "results" / "first_token" / "lora_l1_predictions.csv"
_csv_path.parent.mkdir(parents=True, exist_ok=True)
pd.DataFrame(predictions).to_csv(_csv_path, index=False)
print(f"First-token rows saved → {_csv_path}")
# Out:
# First-token rows saved → /workspace/thesis_circuit_breaker/my_work/results/first_token/lora_l1_predictions.csv

# %% [markdown]
# ## 4b — First-token probability tables (monitoring)
#
# Runs **two passes** over **`probe_prompts`**: (**1**) binary rows → softmax probability on **`VOCAB_ID_TRUE`** / **`VOCAB_ID_FALSE`** at the **last prompt position**; (**2**) numeric rows → softmax mass on the **single token id** Gemma assigns to each digit string **`"0"` … `"9"`** (tries plain digit then a leading space, same spirit as numeric targets in §3).
#
# Results: **`df_binary_token_probs`** and **`df_numeric_digit_probs`**. Progress prints every **`PROB_MONITOR_EVERY`** rows.

# %%
import pandas as pd
import torch.nn.functional as F
from IPython.display import display

PROB_MONITOR_EVERY = max(5, max(1, len(probe_prompts)) // 20)


def _last_vocab_probs(prompt: str) -> torch.Tensor:
    logits, _ = ct_model.feature_intervention(prompt, [])
    last = logits.squeeze(0)[-1, :].float()
    return F.softmax(last, dim=-1)


def _resolve_digit_vocab_id(d: int) -> int:
    """Single-token vocab id Gemma assigns to digit continuation (plain or spaced)."""
    ch = str(int(d))
    for variant in (ch, f" {ch}"):
        tids = ct_tokenizer.encode(variant, add_special_tokens=False)
        if len(tids) == 1:
            return int(tids[0])
    raise ValueError(f"Digit {d!r} must map to a single token; tried {ch!r} and {(' '+ch)!r}")


DIGIT_IDS = [_resolve_digit_vocab_id(d) for d in range(10)]
print(f"Digit vocab ids [0..9]: {DIGIT_IDS}")

binary_list = [p for p in probe_prompts if p.get("task_type", "binary") == "binary"]
numeric_list = [p for p in probe_prompts if p.get("task_type", "binary") == "numeric"]

# --- Pass 1: binary ---
t0 = time.time()
binary_rows = []
for i, entry in enumerate(binary_list, 1):
    probs = _last_vocab_probs(entry["prompt"])
    pt = float(probs[VOCAB_ID_TRUE].item())
    pf = float(probs[VOCAB_ID_FALSE].item())
    binary_rows.append(
        {
            "prompt_id": entry["prompt_id"],
            "family": entry.get("family"),
            "tail": entry.get("tail"),
            "label": entry.get("label"),
            "task_type": entry.get("task_type", "binary"),
            "prob_true": pt,
            "prob_false": pf,
            "prob_mass_tf": pt + pf,
        }
    )
    if PROB_MONITOR_EVERY and (i % PROB_MONITOR_EVERY == 0 or i == len(binary_list)):
        dt = max(time.time() - t0, 1e-6)
        print(
            f"  binary {i}/{len(binary_list)}  "
            f"{i/dt:.2f}/s  ETA {(len(binary_list)-i)/max(i/dt,1e-6):.1f}s"
        )

t1 = time.time()
df_binary_token_probs = pd.DataFrame(binary_rows)
print(f"df_binary_token_probs rows={len(df_binary_token_probs)}  wall={t1-t0:.1f}s")

# --- Pass 2: numeric digit masses ---
numeric_rows = []
t0 = time.time()
for i, entry in enumerate(numeric_list, 1):
    probs = _last_vocab_probs(entry["prompt"])
    row = {
        "prompt_id": entry["prompt_id"],
        "family": entry.get("family"),
        "tail": entry.get("tail"),
        "label": entry.get("label"),
        "label_token": entry.get("label_token"),
        "task_type": entry.get("task_type"),
    }
    mass = 0.0
    for d in range(10):
        p = float(probs[DIGIT_IDS[d]].item())
        row[f"prob_digit_{d}"] = p
        mass += p
    row["prob_mass_digits"] = mass
    numeric_rows.append(row)
    if PROB_MONITOR_EVERY and (i % PROB_MONITOR_EVERY == 0 or i == len(numeric_list)):
        dt = max(time.time() - t0, 1e-6)
        print(
            f"  numeric {i}/{len(numeric_list)}  "
            f"{i/dt:.2f}/s  ETA {(len(numeric_list)-i)/max(i/dt,1e-6):.1f}s"
        )

t1 = time.time()
df_numeric_digit_probs = pd.DataFrame(numeric_rows)
print(f"df_numeric_digit_probs rows={len(df_numeric_digit_probs)}  wall={t1-t0:.1f}s")

display(df_binary_token_probs.head(3))
display(df_numeric_digit_probs.head(3))

FIRST_TOKEN_DIR = MY_WORK / "results" / "first_token"
FIRST_TOKEN_DIR.mkdir(parents=True, exist_ok=True)
stem = PHASE + ("_pilot" if not RUN_FULL else "")
path_bin = FIRST_TOKEN_DIR / f"lora_binary_token_probs_{stem}.csv"
path_num = FIRST_TOKEN_DIR / f"lora_numeric_digit_probs_{stem}.csv"
df_binary_token_probs.to_csv(path_bin, index=False)
df_numeric_digit_probs.to_csv(path_num, index=False)
print(f"Wrote {path_bin}")
print(f"Wrote {path_num}")
# Out:
# Digit vocab ids [0..9]: [235276, 235274, 235284, 235304, 235310, 235308, 235318, 235324, 235321, 235315]
#   binary 15/270  0.85/s  ETA 300.3s
#   binary 30/270  0.84/s  ETA 285.0s
#   binary 45/270  0.84/s  ETA 268.9s
#   binary 60/270  0.84/s  ETA 250.4s
#   binary 75/270  0.84/s  ETA 231.6s
#   binary 90/270  0.84/s  ETA 213.3s
#   binary 105/270  0.85/s  ETA 195.2s
#   binary 120/270  0.85/s  ETA 177.5s
#   binary 135/270  0.84/s  ETA 159.8s
#   binary 150/270  0.84/s  ETA 142.2s
#   binary 165/270  0.84/s  ETA 124.5s
#   binary 180/270  0.84/s  ETA 106.7s
#   binary 195/270  0.84/s  ETA 89.0s
#   binary 210/270  0.84/s  ETA 71.2s
#   binary 225/270  0.84/s  ETA 53.4s
#   binary 240/270  0.84/s  ETA 35.6s
#   binary 255/270  0.84/s  ETA 17.8s
#   binary 270/270  0.84/s  ETA 0.0s
# df_binary_token_probs rows=270  wall=321.0s
#   numeric 15/30  0.83/s  ETA 18.1s
#   numeric 30/30  0.83/s  ETA 0.0s
# df_numeric_digit_probs rows=30  wall=36.1s
#     prompt_id            family           tail  label task_type  prob_true  \
# 0  tri_v2_001  numeric_validity   answer_colon  False    binary   0.006692
# 1  tri_v2_002  numeric_validity   answer_colon   True    binary   0.984912
# 2  tri_v2_003  numeric_validity  true_or_false  False    binary   0.874507
#
#    prob_false  prob_mass_tf
# 0    0.993233      0.999925
# 1    0.014955      0.999867
# 2    0.055905      0.930412
#     prompt_id        family          tail  label label_token task_type  \
# 0  tri_v2_009  numeric_open  answer_colon      6           6   numeric
# 1  tri_v2_010  numeric_open  answer_colon      2           2   numeric
# 2  tri_v2_024  numeric_open  answer_colon      3           3   numeric
#
#    prob_digit_0  prob_digit_1  prob_digit_2  prob_digit_3  prob_digit_4  \
# 0  7.343283e-06      0.000065      0.000079      0.000040      0.000040
# 1  1.073399e-06      0.000033      0.000033      0.000066      0.000031
# 2  6.793150e-07      0.000029      0.000069      0.000025      0.000045
#
#    prob_digit_5  prob_digit_6  prob_digit_7  prob_digit_8  prob_digit_9  \
# 0      0.000026      0.000011      0.000011      0.000004      0.000003
# 1      0.000023      0.000010      0.000010      0.000003      0.000003
# 2      0.000021      0.000019      0.000015      0.000007      0.000005
#
#    prob_mass_digits
# 0          0.000285
# 1          0.000213
# 2          0.000237
# Wrote /workspace/thesis_circuit_breaker/my_work/results/first_token/lora_binary_token_probs_lora_l1.csv
# Wrote /workspace/thesis_circuit_breaker/my_work/results/first_token/lora_numeric_digit_probs_lora_l1.csv

# %% [markdown]
# ## 5 — Attribution + stats loop
#
# Same **`compute_statistics`** schema as **`02`**. Compare in `05_lora_comparison.ipynb` on **`prompt_id`**.
#
# **Checkpoint / resume**
#
# - Any row with **`attribution_succeeded`** already in **`STATS_FILE`** is skipped (no rerun).
#
# - **`RUN_FULL=False`** only appends to **`stats_lora_l1_pilot.json`**.
#
# - **`RUN_FULL=True`** appends to **`stats_lora_l1.json`**. Prompts that succeeded in **`stats_lora_l1_pilot.json`** but are still missing from the full file have their rows **copied** over (instant, no GPU) so you avoid duplicate attribution **and** a completed full run fills **`stats_lora_l1.json`** for **`USE_PILOT=False`** in `05`.

# %%
import importlib
import utils.graph_statistics as gs_mod
importlib.reload(gs_mod)

from circuit_tracer import attribute
from utils.graph_statistics import compute_statistics, load_statistics, append_statistic

def _successful_rows_by_id(rows):
    return {
        e["prompt_id"]: e
        for e in rows
        if e.get("prompt_id") is not None and e.get("attribution_succeeded")
    }

existing = load_statistics(STATS_FILE)
done_rows = _successful_rows_by_id(existing)
done_ids = set(done_rows)

pilot_succ: dict = {}
if RUN_FULL and STATS_FILE.resolve() != PILOT_STATS_FILE.resolve():
    pilot_succ = _successful_rows_by_id(load_statistics(PILOT_STATS_FILE))

n_prev_failed = sum(1 for e in existing if not e.get("attribution_succeeded"))
remaining = [p for p in probe_prompts if p["prompt_id"] not in done_ids]
n_copy_hint = sum(1 for p in remaining if p["prompt_id"] in pilot_succ)

print(f"Stats file (append target) : {STATS_FILE}")
print(f"Already succeeded (here) : {len(done_ids)}")
if RUN_FULL and pilot_succ:
    print(f"Pilot rows to reuse      : {n_copy_hint}")
print(f"Previously failed (here) : {n_prev_failed} (eligible for retry)")
print(f"Remaining to process     : {len(remaining)} prompts")
print()

t0 = time.time()
n_success = 0
n_fail = 0
n_copied = 0
progress_every = 5

for i, entry in enumerate(remaining, start=1):
    pid = entry["prompt_id"]
    task_type = entry.get("task_type", "binary")
    print(f"[{i}/{len(remaining)}] {pid} ({task_type}) ...", end=" ", flush=True)

    if RUN_FULL and pid in pilot_succ:
        append_statistic(dict(pilot_succ[pid]), STATS_FILE)
        n_success += 1
        n_copied += 1
        print("OK (reused pilot row)")
        continue

    try:
        graph = attribute(
            prompt=entry["prompt"],
            model=ct_model,
            attribution_targets=_resolve_attr_targets(entry),
            **ATTR_KWARGS,
        )
        stat = compute_statistics(graph, entry, phase=PHASE)
        append_statistic(stat, STATS_FILE)
        n_success += 1

        del graph
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.synchronize()
            torch.cuda.empty_cache()
            torch.cuda.ipc_collect()

        density  = stat.get("edge_density", float("nan"))
        n_active = stat.get("n_active_features", "?")
        print(f"OK  n_active={n_active}  density={density:.4f}")

    except Exception as exc:
        n_fail += 1
        stat = {
            "prompt_id": pid,
            "phase": PHASE,
            "task_type": task_type,
            "family": entry.get("family"),
            "tail": entry.get("tail"),
            "label": entry["label"],
            "label_token": entry["label_token"],
            "template_id": entry.get("template_id"),
            "attribution_succeeded": False,
            "_error": str(exc),
        }
        append_statistic(stat, STATS_FILE)
        print(f"FAIL: {exc}")
        traceback.print_exc()

    if i % progress_every == 0:
        elapsed = time.time() - t0
        speed   = i / elapsed
        eta     = (len(remaining) - i) / speed if speed > 0 else float("inf")
        print(
            f"[progress] {i}/{len(remaining)} ({i/len(remaining):.0%}) | "
            f"success={n_success}/{n_success+n_fail} | "
            f"{speed:.3f} prompts/s | ETA {eta/60:.1f} min"
        )

print()
print(f"Done. {n_success} ok ({n_copied} reused from pilot), {n_fail} failed in {time.time()-t0:.0f}s.")
print(f"Stats saved to: {STATS_FILE}")
# Out:
# Stats file (append target) : /workspace/thesis_circuit_breaker/my_work/results/statistics/stats_lora_l1.json
# Already succeeded (here) : 0
# Previously failed (here) : 0 (eligible for retry)
# Remaining to process     : 300 prompts
#
# [1/300] tri_v2_001 (binary) ... OK  n_active=21519  density=0.1219
# [2/300] tri_v2_002 (binary) ... OK  n_active=17584  density=0.1265
# [3/300] tri_v2_003 (binary) ... OK  n_active=31121  density=0.1157
# [4/300] tri_v2_004 (binary) ... OK  n_active=26470  density=0.1180
# [5/300] tri_v2_005 (binary) ... OK  n_active=27667  density=0.1180
# [progress] 5/300 (2%) | success=5/5 | 0.015 prompts/s | ETA 338.5 min
# [6/300] tri_v2_006 (binary) ... OK  n_active=20298  density=0.1240
# [7/300] tri_v2_007 (binary) ... OK  n_active=29258  density=0.1159
# [8/300] tri_v2_008 (binary) ... OK  n_active=17834  density=0.1222
# [9/300] tri_v2_009 (numeric) ... OK  n_active=29597  density=0.1184
# [10/300] tri_v2_010 (numeric) ... OK  n_active=29220  density=0.1119
# [progress] 10/300 (3%) | success=10/10 | 0.015 prompts/s | ETA 327.5 min
# [11/300] tri_v2_011 (binary) ... OK  n_active=29563  density=0.1099
# [12/300] tri_v2_012 (binary) ... OK  n_active=22897  density=0.1102
# [13/300] tri_v2_013 (binary) ... OK  n_active=24604  density=0.1079
# [14/300] tri_v2_014 (binary) ... OK  n_active=19312  density=0.1148
# [15/300] tri_v2_015 (binary) ... OK  n_active=24498  density=0.1098
# [progress] 15/300 (5%) | success=15/15 | 0.015 prompts/s | ETA 316.8 min
# [16/300] tri_v2_016 (binary) ... OK  n_active=25015  density=0.1128
# [17/300] tri_v2_017 (binary) ... OK  n_active=24957  density=0.1122
# [18/300] tri_v2_018 (binary) ... OK  n_active=20938  density=0.1248
# [19/300] tri_v2_019 (binary) ... OK  n_active=18267  density=0.1237
# [20/300] tri_v2_020 (binary) ... OK  n_active=25133  density=0.1123
# [progress] 20/300 (7%) | success=20/20 | 0.015 prompts/s | ETA 310.0 min
# [21/300] tri_v2_021 (binary) ... OK  n_active=26596  density=0.1177
# [22/300] tri_v2_022 (binary) ... OK  n_active=28521  density=0.1097
# [23/300] tri_v2_023 (binary) ... OK  n_active=22976  density=0.1179
# [24/300] tri_v2_024 (numeric) ... OK  n_active=29259  density=0.1136
# [25/300] tri_v2_025 (binary) ... OK  n_active=28521  density=0.1097
# [progress] 25/300 (8%) | success=25/25 | 0.015 prompts/s | ETA 305.7 min
# [26/300] tri_v2_026 (binary) ... OK  n_active=21811  density=0.1247
# [27/300] tri_v2_027 (binary) ... OK  n_active=20537  density=0.1121
# [28/300] tri_v2_028 (binary) ... OK  n_active=26669  density=0.1119
# [29/300] tri_v2_029 (binary) ... OK  n_active=20645  density=0.1124
# [30/300] tri_v2_030 (binary) ... OK  n_active=20423  density=0.1221
# [progress] 30/300 (10%) | success=30/30 | 0.015 prompts/s | ETA 302.1 min
# [31/300] tri_v2_031 (binary) ... OK  n_active=18518  density=0.1242
# [32/300] tri_v2_032 (binary) ... OK  n_active=26900  density=0.1177
# [33/300] tri_v2_033 (numeric) ... OK  n_active=29332  density=0.1160
# [34/300] tri_v2_034 (binary) ... OK  n_active=16430  density=0.1349
# [35/300] tri_v2_035 (binary) ... OK  n_active=28757  density=0.1162
# [progress] 35/300 (12%) | success=35/35 | 0.015 prompts/s | ETA 295.8 min
# [36/300] tri_v2_036 (binary) ... OK  n_active=28755  density=0.1092
# [37/300] tri_v2_037 (binary) ... OK  n_active=18698  density=0.1195
# [38/300] tri_v2_038 (binary) ... OK  n_active=25392  density=0.1133
# [39/300] tri_v2_039 (binary) ... OK  n_active=20141  density=0.1321
# [40/300] tri_v2_040 (binary) ... OK  n_active=33008  density=0.1059
# [progress] 40/300 (13%) | success=40/40 | 0.015 prompts/s | ETA 289.7 min
# [41/300] tri_v2_041 (binary) ... OK  n_active=26301  density=0.1167
# [42/300] tri_v2_042 (binary) ... OK  n_active=16334  density=0.1300
# [43/300] tri_v2_043 (binary) ... OK  n_active=19174  density=0.1202
# [44/300] tri_v2_044 (numeric) ... OK  n_active=29623  density=0.1125
# [45/300] tri_v2_045 (binary) ... OK  n_active=26683  density=0.1160
# [progress] 45/300 (15%) | success=45/45 | 0.015 prompts/s | ETA 283.7 min
# [46/300] tri_v2_046 (numeric) ... OK  n_active=29783  density=0.1110
# [47/300] tri_v2_047 (binary) ... OK  n_active=28388  density=0.1105
# [48/300] tri_v2_048 (binary) ... OK  n_active=22083  density=0.1189
# [49/300] tri_v2_049 (binary) ... OK  n_active=29531  density=0.1090
# [50/300] tri_v2_050 (binary) ... OK  n_active=30063  density=0.1158
# [progress] 50/300 (17%) | success=50/50 | 0.015 prompts/s | ETA 278.9 min
# [51/300] tri_v2_051 (binary) ... OK  n_active=15943  density=0.1253
# [52/300] tri_v2_052 (binary) ... OK  n_active=16430  density=0.1349
# [53/300] tri_v2_053 (numeric) ... OK  n_active=30417  density=0.1190
# [54/300] tri_v2_054 (binary) ... OK  n_active=26453  density=0.1175
# [55/300] tri_v2_055 (binary) ... OK  n_active=21046  density=0.1268
# [progress] 55/300 (18%) | success=55/55 | 0.015 prompts/s | ETA 272.6 min
# [56/300] tri_v2_056 (binary) ... OK  n_active=20192  density=0.1159
# [57/300] tri_v2_057 (numeric) ... OK  n_active=29212  density=0.1134
# [58/300] tri_v2_058 (binary) ... OK  n_active=18858  density=0.1246
# [59/300] tri_v2_059 (binary) ... OK  n_active=32177  density=0.1058
# [60/300] tri_v2_060 (binary) ... OK  n_active=33627  density=0.1070
# [progress] 60/300 (20%) | success=60/60 | 0.015 prompts/s | ETA 267.1 min
# [61/300] tri_v2_061 (binary) ... OK  n_active=17005  density=0.1249
# [62/300] tri_v2_062 (binary) ... OK  n_active=19488  density=0.1206
# [63/300] tri_v2_063 (binary) ... OK  n_active=22350  density=0.1284
# [64/300] tri_v2_064 (binary) ... OK  n_active=20678  density=0.1228
# [65/300] tri_v2_065 (binary) ... OK  n_active=16042  density=0.1295
# [progress] 65/300 (22%) | success=65/65 | 0.015 prompts/s | ETA 260.2 min
# [66/300] tri_v2_066 (numeric) ... OK  n_active=29409  density=0.1163
# [67/300] tri_v2_067 (binary) ... OK  n_active=30152  density=0.1149
# [68/300] tri_v2_068 (binary) ... OK  n_active=19584  density=0.1171
# [69/300] tri_v2_069 (binary) ... OK  n_active=18359  density=0.1235
# [70/300] tri_v2_070 (binary) ... OK  n_active=30557  density=0.1151
# [progress] 70/300 (23%) | success=70/70 | 0.015 prompts/s | ETA 254.8 min
# [71/300] tri_v2_071 (binary) ... OK  n_active=16278  density=0.1332
# [72/300] tri_v2_072 (binary) ... OK  n_active=25050  density=0.1042
# [73/300] tri_v2_073 (binary) ... OK  n_active=25360  density=0.1193
# [74/300] tri_v2_074 (binary) ... OK  n_active=19211  density=0.1154
# [75/300] tri_v2_075 (binary) ... OK  n_active=29931  density=0.1114
# [progress] 75/300 (25%) | success=75/75 | 0.015 prompts/s | ETA 249.0 min
# [76/300] tri_v2_076 (binary) ... OK  n_active=16979  density=0.1187
# [77/300] tri_v2_077 (binary) ... OK  n_active=16881  density=0.1211
# [78/300] tri_v2_078 (binary) ... OK  n_active=17344  density=0.1175
# [79/300] tri_v2_079 (binary) ... OK  n_active=20141  density=0.1320
# [80/300] tri_v2_080 (binary) ... OK  n_active=23765  density=0.1127
# [progress] 80/300 (27%) | success=80/80 | 0.015 prompts/s | ETA 242.6 min
# [81/300] tri_v2_081 (numeric) ... OK  n_active=31177  density=0.1137
# [82/300] tri_v2_082 (binary) ... OK  n_active=20822  density=0.1300
# [83/300] tri_v2_083 (binary) ... OK  n_active=18535  density=0.1322
# [84/300] tri_v2_084 (binary) ... OK  n_active=32953  density=0.1086
# [85/300] tri_v2_085 (binary) ... OK  n_active=18019  density=0.1217
# [progress] 85/300 (28%) | success=85/85 | 0.015 prompts/s | ETA 237.1 min
# [86/300] tri_v2_086 (binary) ... OK  n_active=25439  density=0.1180
# [87/300] tri_v2_087 (binary) ... OK  n_active=22395  density=0.1309
# [88/300] tri_v2_088 (numeric) ... OK  n_active=29734  density=0.1158
# [89/300] tri_v2_089 (numeric) ... OK  n_active=29414  density=0.1157
# [90/300] tri_v2_090 (binary) ... OK  n_active=19980  density=0.1093
# [progress] 90/300 (30%) | success=90/90 | 0.015 prompts/s | ETA 231.7 min
# [91/300] tri_v2_091 (binary) ... OK  n_active=19349  density=0.1125
# [92/300] tri_v2_092 (binary) ... OK  n_active=18427  density=0.1234
# [93/300] tri_v2_093 (binary) ... OK  n_active=22702  density=0.1207
# [94/300] tri_v2_094 (binary) ... OK  n_active=30123  density=0.1126
# [95/300] tri_v2_095 (binary) ... OK  n_active=28438  density=0.1101
# [progress] 95/300 (32%) | success=95/95 | 0.015 prompts/s | ETA 226.1 min
# [96/300] tri_v2_096 (binary) ... OK  n_active=24266  density=0.1072
# [97/300] tri_v2_097 (binary) ... OK  n_active=23741  density=0.1115
# [98/300] tri_v2_098 (binary) ... OK  n_active=22477  density=0.1102
# [99/300] tri_v2_099 (binary) ... OK  n_active=26504  density=0.1189
# [100/300] tri_v2_100 (binary) ... OK  n_active=18995  density=0.1273
# [progress] 100/300 (33%) | success=100/100 | 0.015 prompts/s | ETA 220.3 min
# [101/300] tri_v2_101 (binary) ... OK  n_active=20434  density=0.1120
# [102/300] tri_v2_102 (binary) ... OK  n_active=17674  density=0.1277
# [103/300] tri_v2_103 (binary) ... OK  n_active=29022  density=0.1106
# [104/300] tri_v2_104 (numeric) ... OK  n_active=29716  density=0.1190
# [105/300] tri_v2_105 (binary) ... OK  n_active=27844  density=0.1181
# [progress] 105/300 (35%) | success=105/105 | 0.015 prompts/s | ETA 214.9 min
# [106/300] tri_v2_106 (binary) ... OK  n_active=17005  density=0.1198
# [107/300] tri_v2_107 (binary) ... OK  n_active=19773  density=0.1276
# [108/300] tri_v2_108 (binary) ... OK  n_active=25268  density=0.1193
# [109/300] tri_v2_109 (binary) ... OK  n_active=21688  density=0.1138
# [110/300] tri_v2_110 (binary) ... OK  n_active=20299  density=0.1237
# [progress] 110/300 (37%) | success=110/110 | 0.015 prompts/s | ETA 209.2 min
# [111/300] tri_v2_111 (binary) ... OK  n_active=25833  density=0.1129
# [112/300] tri_v2_112 (binary) ... OK  n_active=29873  density=0.1153
# [113/300] tri_v2_113 (binary) ... OK  n_active=20839  density=0.1097
# [114/300] tri_v2_114 (binary) ... OK  n_active=32868  density=0.1052
# [115/300] tri_v2_115 (binary) ... OK  n_active=17620  density=0.1256
# [progress] 115/300 (38%) | success=115/115 | 0.015 prompts/s | ETA 204.2 min
# [116/300] tri_v2_116 (binary) ... OK  n_active=20723  density=0.1272
# [117/300] tri_v2_117 (binary) ... OK  n_active=22689  density=0.1250
# [118/300] tri_v2_118 (numeric) ... OK  n_active=29337  density=0.1154
# [119/300] tri_v2_119 (binary) ... OK  n_active=18698  density=0.1195
# [120/300] tri_v2_120 (binary) ... OK  n_active=22706  density=0.1216
# [progress] 120/300 (40%) | success=120/120 | 0.015 prompts/s | ETA 198.7 min
# [121/300] tri_v2_121 (binary) ... OK  n_active=22689  density=0.1250
# [122/300] tri_v2_122 (binary) ... OK  n_active=28011  density=0.1174
# [123/300] tri_v2_123 (binary) ... OK  n_active=16842  density=0.1207
# [124/300] tri_v2_124 (binary) ... OK  n_active=29884  density=0.1155
# [125/300] tri_v2_125 (binary) ... OK  n_active=27795  density=0.1180
# [progress] 125/300 (42%) | success=125/125 | 0.015 prompts/s | ETA 193.4 min
# [126/300] tri_v2_126 (binary) ... OK  n_active=19943  density=0.1143
# [127/300] tri_v2_127 (binary) ... OK  n_active=19772  density=0.1109
# [128/300] tri_v2_128 (binary) ... OK  n_active=20775  density=0.1298
# [129/300] tri_v2_129 (binary) ... OK  n_active=22882  density=0.1209
# [130/300] tri_v2_130 (binary) ... OK  n_active=21088  density=0.1269
# [progress] 130/300 (43%) | success=130/130 | 0.015 prompts/s | ETA 187.6 min
# [131/300] tri_v2_131 (binary) ... OK  n_active=17704  density=0.1263
# [132/300] tri_v2_132 (binary) ... OK  n_active=30934  density=0.1124
# [133/300] tri_v2_133 (binary) ... OK  n_active=25424  density=0.1183
# [134/300] tri_v2_134 (binary) ... OK  n_active=16669  density=0.1193
# [135/300] tri_v2_135 (binary) ... OK  n_active=16100  density=0.1220
# [progress] 135/300 (45%) | success=135/135 | 0.015 prompts/s | ETA 181.9 min
# [136/300] tri_v2_136 (binary) ... OK  n_active=28474  density=0.1106
# [137/300] tri_v2_137 (binary) ... OK  n_active=24903  density=0.1067
# [138/300] tri_v2_138 (binary) ... OK  n_active=16763  density=0.1221
# [139/300] tri_v2_139 (binary) ... OK  n_active=23503  density=0.1059
# [140/300] tri_v2_140 (binary) ... OK  n_active=19195  density=0.1273
# [progress] 140/300 (47%) | success=140/140 | 0.015 prompts/s | ETA 176.2 min
# [141/300] tri_v2_141 (binary) ... OK  n_active=31015  density=0.1063
# [142/300] tri_v2_142 (numeric) ... OK  n_active=29188  density=0.1126
# [143/300] tri_v2_143 (binary) ... OK  n_active=19416  density=0.1068
# [144/300] tri_v2_144 (binary) ... OK  n_active=17239  density=0.1237
# [145/300] tri_v2_145 (binary) ... OK  n_active=21568  density=0.1203
# [progress] 145/300 (48%) | success=145/145 | 0.015 prompts/s | ETA 170.7 min
# [146/300] tri_v2_146 (binary) ... OK  n_active=18449  density=0.1212
# [147/300] tri_v2_147 (binary) ... OK  n_active=23664  density=0.1109
# [148/300] tri_v2_148 (binary) ... OK  n_active=21739  density=0.1262
# [149/300] tri_v2_149 (binary) ... OK  n_active=17115  density=0.1243
# [150/300] tri_v2_150 (binary) ... OK  n_active=28593  density=0.1090
# [progress] 150/300 (50%) | success=150/150 | 0.015 prompts/s | ETA 165.1 min
# [151/300] tri_v2_151 (binary) ... OK  n_active=29123  density=0.1151
# [152/300] tri_v2_152 (binary) ... OK  n_active=18313  density=0.1242
# [153/300] tri_v2_153 (numeric) ... OK  n_active=30457  density=0.1156
# [154/300] tri_v2_154 (binary) ... OK  n_active=19204  density=0.1202
# [155/300] tri_v2_155 (numeric) ... OK  n_active=31096  density=0.1185
# [progress] 155/300 (52%) | success=155/155 | 0.015 prompts/s | ETA 159.7 min
# [156/300] tri_v2_156 (binary) ... OK  n_active=19098  density=0.1193
# [157/300] tri_v2_157 (binary) ... OK  n_active=24161  density=0.1090
# [158/300] tri_v2_158 (binary) ... OK  n_active=20097  density=0.1301
# [159/300] tri_v2_159 (binary) ... OK  n_active=28079  density=0.1166
# [160/300] tri_v2_160 (numeric) ... OK  n_active=31078  density=0.1176
# [progress] 160/300 (53%) | success=160/160 | 0.015 prompts/s | ETA 154.4 min
# [161/300] tri_v2_161 (binary) ... OK  n_active=19629  density=0.1258
# [162/300] tri_v2_162 (binary) ... OK  n_active=26720  density=0.1171
# [163/300] tri_v2_163 (binary) ... OK  n_active=18359  density=0.1235
# [164/300] tri_v2_164 (numeric) ...

# %% [markdown]
# ## 6 — Scale-up decision
#
# After the pilot: if **`n_success >= N_PILOT * 0.9`** (or whenever you want the full probe set),
#
# set **`RUN_FULL = True`** in §1 and **re-run from §1**.
#
# §5 skips IDs already recorded in **`stats_lora_l1.json`** (if any) **and**
#
# **reuses pilot successes by copying rows** — no duplicate attribution cost for prompts that finished during the pilot.

# %%
final_stats = load_statistics(STATS_FILE)
n_ok    = sum(1 for s in final_stats if s.get("attribution_succeeded"))
n_total = len(final_stats)

print(f"=== Post-run summary ===")
print(f"Stats file : {STATS_FILE}")
print(f"Total rows : {n_total}")
print(f"Succeeded  : {n_ok}  ({n_ok/max(n_total,1):.1%})")
print()
if not RUN_FULL:
    print("Pilot complete.")
    print("If results look good: set RUN_FULL=True in §1 and re-run from §1 onwards.")
    print("Full run saves to:", FULL_STATS_FILE)
else:
    print("Full run complete. Proceed to 05_lora_comparison.ipynb.")
